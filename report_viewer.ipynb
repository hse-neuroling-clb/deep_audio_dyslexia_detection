# %%
from pathlib import Path
import pandas as pd

# Root directory containing subdirectories
root_dir = Path("./output_old/folds_0.15")

# Find all report.csv files in subdirectories
csv_files = list(root_dir.glob("*/report.csv"))

# Read and concatenate all CSVs
dfs = [pd.read_csv(f) for f in csv_files]
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined CSV
combined_df
# Out:
#                                                 name  \
# 0  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 1  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 2  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 3  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 4  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 5  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
# 6  lobster+trick+zoo_on-subset_enc-whisper60s_mea...
#
#                  DATASET_NAMES TEST_DATASET_NAME  THRESHOLD_SPLITS  \
# 0  ['lobster', 'trick', 'zoo']            subset                 3
# 1  ['lobster', 'trick', 'zoo']            subset                 3
# 2  ['lobster', 'trick', 'zoo']            subset                 3
# 3  ['lobster', 'trick', 'zoo']            subset                 3
# 4  ['lobster', 'trick', 'zoo']            subset                 3
# 5  ['lobster', 'trick', 'zoo']            subset                 3
# 6  ['lobster', 'trick', 'zoo']            subset                 3
#
#   AUDIO_ENCODER_TYPE  BALANCE_DATASET  balance_lost_records  working_records  \
# 0    whisper60s_mean             True                   819              369
# 1    whisper60s_mean             True                   819              369
# 2    whisper60s_mean             True                   819              369
# 3    whisper60s_mean             True                   819              369
# 4    whisper60s_mean             True                   819              369
# 5    whisper60s_mean             True                   819              369
# 6    whisper60s_mean             True                   819              369
#
#         MSE  test_MAE  ...  Task lobster/10/support  Task lobster/accuracy  \
# 0  0.050268  0.167715  ...                     10.0               1.000000
# 1  0.032650  0.123582  ...                      9.0               0.928571
# 2  0.019191  0.105810  ...                      7.0               0.900000
# 3  0.018511  0.107385  ...                      9.0               1.000000
# 4  0.015179  0.091069  ...                     11.0               0.833333
# 5  0.090904  0.259413  ...                     12.0               0.705882
# 6  0.027994  0.128743  ...                     10.0               0.928571
#
#    Task lobster/macro avg/precision  Task lobster/macro avg/recall  \
# 0                          1.000000                       1.000000
# 1                          0.950000                       0.900000
# 2                          0.937500                       0.833333
# 3                          1.000000                       1.000000
# 4                          0.454545                       0.454545
# 5                          0.352941                       0.500000
# 6                          0.954545                       0.875000
#
#    Task lobster/macro avg/f1-score Task lobster/macro avg/support  \
# 0                         1.000000                           12.0
# 1                         0.918129                           14.0
# 2                         0.866667                           10.0
# 3                         1.000000                           11.0
# 4                         0.454545                           12.0
# 5                         0.413793                           17.0
# 6                         0.904762                           14.0
#
#    Task lobster/weighted avg/precision  Task lobster/weighted avg/recall  \
# 0                             1.000000                          1.000000
# 1                             0.935714                          0.928571
# 2                             0.912500                          0.900000
# 3                             1.000000                          1.000000
# 4                             0.833333                          0.833333
# 5                             0.498270                          0.705882
# 6                             0.935065                          0.928571
#
#    Task lobster/weighted avg/f1-score  Task lobster/weighted avg/support
# 0                            1.000000                               12.0
# 1                            0.926483                               14.0
# 2                            0.893333                               10.0
# 3                            1.000000                               11.0
# 4                            0.833333                               12.0
# 5                            0.584178                               17.0
# 6                            0.925170                               14.0
#
# [7 rows x 186 columns]
